# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import plotly as ply

# %%
county_house = pd.read_csv("/Users/abhiteshkumar/Desktop/project/Final_project_Covid19/Housing/County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
county_house.head(10)
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     County        CA    CA
# 1       139         1         Cook County     County        IL    IL
# 2      1090         2       Harris County     County        TX    TX
# 3      2402         3     Maricopa County     County        AZ    AZ
# 4      2841         4    San Diego County     County        CA    CA
# 5      1286         5       Orange County     County        CA    CA
# 6       581         6        Kings County     County        NY    NY
# 7      2964         7   Miami-Dade County     County        FL    FL
# 8       978         8       Dallas County     County        TX    TX
# 9      1347         9       Queens County     County        NY    NY
#
#                                    Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0         Los Angeles-Long Beach-Anaheim              6                 37
# ...

# %%
SDhouse = county_house.loc[county_house["RegionName"] == "San Diego County"]
SDhouse.head(10)
# Out:
#    RegionID  SizeRank        RegionName RegionType StateName State  \
# 4      2841         4  San Diego County     County        CA    CA
#
#                 Metro  StateCodeFIPS  MunicipalCodeFIPS  2000-01-31  ...  \
# 4  San Diego-Carlsbad              6                 73    229073.0  ...
#
#    2021-06-30  2021-07-31  2021-08-31  2021-09-30  2021-10-31  2021-11-30  \
# 4    765864.0    789895.0    804648.0    814441.0    819215.0    826807.0
#
#    2021-12-31  2022-01-31  2022-02-28  2022-03-31
# 4    838226.0    858817.0    879278.0    902655.0
#
# [1 rows x 276 columns]

# %%
SDIndex = pd.read_excel('/Users/abhiteshkumar/Desktop/project/Final_project_Covid19/Housing/San_Diego_Home_Value_Index.xlsx', index_col=0)
SDIndex.head()
# Out:
#             Home Value Index
# Date
# 2000-01-31            229073
# 2000-02-29            230320
# 2000-03-31            231670
# 2000-04-30            234682
# 2000-05-31            237569
