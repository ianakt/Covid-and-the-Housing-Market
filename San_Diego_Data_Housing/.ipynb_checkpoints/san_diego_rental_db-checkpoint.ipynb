# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading CSVs

# %%
city_zip_to_load = "San_Diego_Zip_Codes.csv"
city_rental_to_load = "Zip_ZORI_AllHomesPlusMultifamily_Smoothed.csv"

# %%
city_zip_df = pd.read_csv(city_zip_to_load)
city_zip_df.head(10)
# Out:
#    ZIP Code Classification         City Population Area Code(s)
# 0     91901        General       Alpine     17,403          619
# 1     91902        General       Bonita     17,653          619
# 2     91905        General    Boulevard      1,700      619/760
# 3     91906        General        Campo      3,627      619/858
# 4     91910        General  Chula Vista     75,802          619
# 5     91911        General  Chula Vista     82,999          619
# 6     91913        General  Chula Vista     40,971          619
# 7     91914        General  Chula Vista     15,448          619
# 8     91915        General  Chula Vista     24,659          619
# 9     91916        General     Descanso      1,622      619/858

# %%
city_rent_df = pd.read_csv(city_rental_to_load)
city_rent_df.head(10)
# Out:
#    RegionID  RegionName  SizeRank       MsaName  2014-01  2014-02  2014-03  \
# 0     61639       10025         1  New York, NY   3093.0   3013.0   3103.0
# 1     84654       60657         2   Chicago, IL   1478.0   1513.0   1512.0
# 2     61637       10023         3  New York, NY   3244.0   3263.0   3305.0
# 3     91982       77494         4   Houston, TX   1405.0   1468.0   1474.0
# 4     84616       60614         5   Chicago, IL   1673.0   1701.0   1711.0
# 5     91940       77449         6   Houston, TX   1151.0   1146.0   1148.0
# 6     61616       10002         7  New York, NY   2994.0   2903.0   2966.0
# 7     91733       77084         8   Houston, TX   1047.0   1120.0   1124.0
# 8     93144       79936         9   El Paso, TX   1048.0   1034.0   1040.0
# 9     84640       60640        10   Chicago, IL   1209.0   1222.0   1211.0
#
#    2014-04  2014-05  2014-06  ...  2021-07  2021-08  2021-09  2021-10  \
# 0   3129.0   3119.0   3121.0  ...   3319.0   3397.0   3422.0   3485.0
# ...

# %% [markdown]
# ## Zip Code Cleanup

# %%
zip_code_df = city_zip_df.drop(['Classification','City','Population','Area Code(s)'],axis=1)
zip_code_df
# Out:
#      ZIP Code
# 0       91901
# 1       91902
# 2       91905
# 3       91906
# 4       91910
# ..        ...
# 101     92145
# 102     92147
# 103     92154
# 104     92155
# 105     92173
#
# [106 rows x 1 columns]

# %%
zip_count = zip_code_df.iat[103,0]
zip_count
# Out:
# 92154

# %% [markdown]
# ## Rental data for San Diego county based on ZIP codes (All Years)

# %%
count = 0
while (count < 2):

    zip_count = zip_code_df.iat[count,0]

    sd_rent = city_rent_df.loc[city_rent_df['RegionName']== zip_count]
    print(sd_rent)
    
    count = count + 1
# Out:
# Empty DataFrame
# Columns: [RegionID, RegionName, SizeRank, MsaName, 2014-01, 2014-02, 2014-03, 2014-04, 2014-05, 2014-06, 2014-07, 2014-08, 2014-09, 2014-10, 2014-11, 2014-12, 2015-01, 2015-02, 2015-03, 2015-04, 2015-05, 2015-06, 2015-07, 2015-08, 2015-09, 2015-10, 2015-11, 2015-12, 2016-01, 2016-02, 2016-03, 2016-04, 2016-05, 2016-06, 2016-07, 2016-08, 2016-09, 2016-10, 2016-11, 2016-12, 2017-01, 2017-02, 2017-03, 2017-04, 2017-05, 2017-06, 2017-07, 2017-08, 2017-09, 2017-10, 2017-11, 2017-12, 2018-01, 2018-02, 2018-03, 2018-04, 2018-05, 2018-06, 2018-07, 2018-08, 2018-09, 2018-10, 2018-11, 2018-12, 2019-01, 2019-02, 2019-03, 2019-04, 2019-05, 2019-06, 2019-07, 2019-08, 2019-09, 2019-10, 2019-11, 2019-12, 2020-01, 2020-02, 2020-03, 2020-04, 2020-05, 2020-06, 2020-07, 2020-08, 2020-09, 2020-10, 2020-11, 2020-12, 2021-01, 2021-02, 2021-03, 2021-04, 2021-05, 2021-06, 2021-07, 2021-08, 2021-09, 2021-10, 2021-11, 2021-12, ...]
# Index: []
#
# [0 rows x 104 columns]
# Empty DataFrame
# ...
