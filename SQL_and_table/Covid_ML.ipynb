# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
covid_df = pd.read_csv("/Users/abhiteshkumar/Desktop/Bootcamp work/Module 20/covid_data.csv")

# %%
covid_df.head()
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  2022-04-27  2020-01-01  2022-04-23  By Total   NaN    NaN  United States
# 1  2022-04-27  2020-01-01  2022-04-23  By Total   NaN    NaN  United States
# 2  2022-04-27  2020-01-01  2022-04-23  By Total   NaN    NaN  United States
# 3  2022-04-27  2020-01-01  2022-04-23  By Total   NaN    NaN  United States
# 4  2022-04-27  2020-01-01  2022-04-23  By Total   NaN    NaN  United States
#
#          Sex     Age Group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0  All Sexes      All Ages         993966.0     7834102.0          880026.0
# 1  All Sexes  Under 1 year            266.0       43796.0             546.0
# 2  All Sexes    0-17 years           1017.0       77689.0            1575.0
# 3  All Sexes     1-4 years            130.0        8176.0             319.0
# 4  All Sexes    5-14 years            325.0       12992.0             453.0
#
# ...

# %%
covid_df = covid_df.drop(columns=["Footnote", "Data As Of", "Start Date", "End Date", "Group"])
covid_df.head()
# Out:
#    Year  Month          State        Sex     Age Group  COVID-19 Deaths  \
# 0   NaN    NaN  United States  All Sexes      All Ages         993966.0
# 1   NaN    NaN  United States  All Sexes  Under 1 year            266.0
# 2   NaN    NaN  United States  All Sexes    0-17 years           1017.0
# 3   NaN    NaN  United States  All Sexes     1-4 years            130.0
# 4   NaN    NaN  United States  All Sexes    5-14 years            325.0
#
#    Total Deaths  Pneumonia Deaths  Pneumonia and COVID-19 Deaths  \
# 0     7834102.0          880026.0                       513999.0
# 1       43796.0             546.0                           34.0
# 2       77689.0            1575.0                          273.0
# 3        8176.0             319.0                           31.0
# 4       12992.0             453.0                          106.0
#
#    Influenza Deaths  Pneumonia, Influenza, or COVID-19 Deaths
# 0           11076.0                                 1369441.0
# ...

# %%
covid_df.dropna()
# Out:
#          Year  Month          State        Sex     Age Group  COVID-19 Deaths  \
# 10819  2020.0    1.0  United States  All Sexes   18-29 years              0.0
# 10862  2020.0    1.0  United States  All Sexes   25-34 years              0.0
# 11018  2020.0    1.0  United States  All Sexes      All Ages              5.0
# 11019  2020.0    1.0  United States  All Sexes  Under 1 year              0.0
# 11020  2020.0    1.0  United States  All Sexes    0-17 years              0.0
# ...       ...    ...            ...        ...           ...              ...
# 88098  2022.0    4.0    Puerto Rico       Male     1-4 years              0.0
# 88099  2022.0    4.0    Puerto Rico       Male    5-14 years              0.0
# 88101  2022.0    4.0    Puerto Rico       Male   18-29 years              0.0
# 88114  2022.0    4.0    Puerto Rico     Female     1-4 years              0.0
# 88115  2022.0    4.0    Puerto Rico     Female    5-14 years              0.0
#
# ...

# %%
covid_df["Year"].dropna()
covid_df
# Out:
#          Year  Month          State        Sex          Age Group  \
# 0         NaN    NaN  United States  All Sexes           All Ages
# 1         NaN    NaN  United States  All Sexes       Under 1 year
# 2         NaN    NaN  United States  All Sexes         0-17 years
# 3         NaN    NaN  United States  All Sexes          1-4 years
# 4         NaN    NaN  United States  All Sexes         5-14 years
# ...       ...    ...            ...        ...                ...
# 88123  2022.0    4.0    Puerto Rico     Female        50-64 years
# 88124  2022.0    4.0    Puerto Rico     Female        55-64 years
# 88125  2022.0    4.0    Puerto Rico     Female        65-74 years
# 88126  2022.0    4.0    Puerto Rico     Female        75-84 years
# 88127  2022.0    4.0    Puerto Rico     Female  85 years and over
#
#        COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0             993966.0     7834102.0          880026.0
# 1                266.0       43796.0             546.0
# ...

# %%
covid_df['Year'] = covid_df['Year'].apply(np.int32)
covid_df()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4c/scv9smqd0kscq_q457qdhvlw0000gn/T/ipykernel_13196/3078619850.py in <module>
# ----> 1 covid_df['Year'] = covid_df['Year'].apply(np.int32)
#       2 covid_df()
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
# ...
